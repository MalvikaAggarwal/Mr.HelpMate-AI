# %% [markdown]
# ## Installation
# Install required packages before running the notebook.

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: aiohappyeyeballs==2.6.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.6.1)
# Requirement already satisfied: aiohttp==3.11.18 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (3.11.18)
# Requirement already satisfied: aiosignal==1.3.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: annotated-types==0.7.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: anyio==4.9.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (4.9.0)
# Requirement already satisfied: asgiref==3.8.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (3.8.1)
# Requirement already satisfied: attrs==25.3.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (25.3.0)
# Requirement already satisfied: backoff==2.2.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (2.2.1)
# Requirement already satisfied: bcrypt==4.3.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (4.3.0)
# Requirement already satisfied: build==1.2.2.post1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 10)) (1.2.2.post1)
# Requirement already satisfied: cachetools==5.5.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 11)) (5.5.2)
# Requirement already satisfied: certifi==2025.4.26 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (2025.4.26)
# Requirement already satisfied: charset-normalizer==3.4.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (3.4.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (0.7.6)
# Requirement already satisfied: chromadb==1.0.7 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (1.0.7)
# Requirement already satisfied: click==8.1.8 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (8.1.8)
# Requirement already satisfied: coloredlogs==15.0.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (15.0.1)
# Requirement already satisfied: dataclasses-json==0.6.7 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (0.6.7)
# Requirement already satisfied: Deprecated==1.2.18 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 19)) (1.2.18)
# Requirement already satisfied: distro==1.9.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 20)) (1.9.0)
# Requirement already satisfied: durationpy==0.9 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 21)) (0.9)
# Requirement already satisfied: fastapi==0.115.9 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 22)) (0.115.9)
# Requirement already satisfied: filelock==3.18.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 23)) (3.18.0)
# Requirement already satisfied: flatbuffers==25.2.10 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 24)) (25.2.10)
# Requirement already satisfied: frozenlist==1.6.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 25)) (1.6.0)
# Requirement already satisfied: fsspec==2025.3.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 26)) (2025.3.2)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 27)) (0.6.15)
# Requirement already satisfied: google-api-core==2.24.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 28)) (2.24.2)
# Requirement already satisfied: google-api-python-client==2.169.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 29)) (2.169.0)
# Requirement already satisfied: google-auth==2.39.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 30)) (2.39.0)
# Requirement already satisfied: google-auth-httplib2==0.2.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 31)) (0.2.0)
# Requirement already satisfied: google-generativeai==0.8.5 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 32)) (0.8.5)
# Requirement already satisfied: googleapis-common-protos==1.70.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 33)) (1.70.0)
# Requirement already satisfied: greenlet==3.2.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 34)) (3.2.1)
# Requirement already satisfied: grpcio==1.71.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 35)) (1.71.0)
# Requirement already satisfied: grpcio-status==1.71.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 36)) (1.71.0)
# Requirement already satisfied: h11==0.16.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 37)) (0.16.0)
# Requirement already satisfied: httpcore==1.0.9 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 38)) (1.0.9)
# Requirement already satisfied: httplib2==0.22.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 39)) (0.22.0)
# Requirement already satisfied: httptools==0.6.4 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 40)) (0.6.4)
# Requirement already satisfied: httpx==0.28.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 41)) (0.28.1)
# Requirement already satisfied: httpx-sse==0.4.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 42)) (0.4.0)
# Requirement already satisfied: huggingface-hub==0.30.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 43)) (0.30.2)
# Requirement already satisfied: humanfriendly==10.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 44)) (10.0)
# Requirement already satisfied: idna==3.10 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 45)) (3.10)
# Requirement already satisfied: importlib_metadata==8.6.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 46)) (8.6.1)
# Requirement already satisfied: importlib_resources==6.5.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 47)) (6.5.2)
# Requirement already satisfied: Jinja2==3.1.6 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 48)) (3.1.6)
# Requirement already satisfied: joblib==1.4.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 49)) (1.4.2)
# Requirement already satisfied: jsonpatch==1.33 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 50)) (1.33)
# Requirement already satisfied: jsonpointer==3.0.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 51)) (3.0.0)
# Requirement already satisfied: jsonschema==4.23.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 52)) (4.23.0)
# Requirement already satisfied: jsonschema-specifications==2025.4.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 53)) (2025.4.1)
# Requirement already satisfied: kubernetes==32.0.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 54)) (32.0.1)
# Requirement already satisfied: langchain==0.3.25 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 55)) (0.3.25)
# Requirement already satisfied: langchain-community==0.3.23 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 56)) (0.3.23)
# Requirement already satisfied: langchain-core==0.3.58 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 57)) (0.3.58)
# Requirement already satisfied: langchain-text-splitters==0.3.8 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 58)) (0.3.8)
# Requirement already satisfied: langsmith==0.3.42 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 59)) (0.3.42)
# Requirement already satisfied: markdown-it-py==3.0.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 60)) (3.0.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 61)) (3.0.2)
# Requirement already satisfied: marshmallow==3.26.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 62)) (3.26.1)
# Requirement already satisfied: mdurl==0.1.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 63)) (0.1.2)
# Requirement already satisfied: mmh3==5.1.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 64)) (5.1.0)
# Requirement already satisfied: mpmath==1.3.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 65)) (1.3.0)
# Requirement already satisfied: multidict==6.4.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 66)) (6.4.3)
# Requirement already satisfied: mypy_extensions==1.1.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 67)) (1.1.0)
# Requirement already satisfied: networkx==3.4.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 68)) (3.4.2)
# Requirement already satisfied: numpy==2.2.5 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 69)) (2.2.5)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 70)) (12.4.5.8)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 71)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 72)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 73)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 74)) (9.1.0.70)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 75)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 76)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 77)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 78)) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 79)) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 80)) (2.21.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 81)) (12.4.127)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 82)) (12.4.127)
# Requirement already satisfied: oauthlib==3.2.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 83)) (3.2.2)
# Requirement already satisfied: onnxruntime==1.21.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 84)) (1.21.1)
# Requirement already satisfied: opentelemetry-api==1.32.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 85)) (1.32.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.32.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 86)) (1.32.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.32.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 87)) (1.32.1)
# Requirement already satisfied: opentelemetry-instrumentation==0.53b1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 88)) (0.53b1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.53b1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 89)) (0.53b1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi==0.53b1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 90)) (0.53b1)
# Requirement already satisfied: opentelemetry-proto==1.32.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 91)) (1.32.1)
# Requirement already satisfied: opentelemetry-sdk==1.32.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 92)) (1.32.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.53b1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 93)) (0.53b1)
# Requirement already satisfied: opentelemetry-util-http==0.53b1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 94)) (0.53b1)
# Requirement already satisfied: orjson==3.10.18 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 95)) (3.10.18)
# Requirement already satisfied: overrides==7.7.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 96)) (7.7.0)
# Requirement already satisfied: packaging==24.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 97)) (24.2)
# Requirement already satisfied: pillow==11.2.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 98)) (11.2.1)
# Requirement already satisfied: posthog==4.0.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 99)) (4.0.1)
# Requirement already satisfied: propcache==0.3.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 100)) (0.3.1)
# Requirement already satisfied: proto-plus==1.26.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 101)) (1.26.1)
# Requirement already satisfied: protobuf==5.29.4 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 102)) (5.29.4)
# Requirement already satisfied: pyasn1==0.6.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 103)) (0.6.1)
# Requirement already satisfied: pyasn1_modules==0.4.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 104)) (0.4.2)
# Requirement already satisfied: pydantic==2.11.4 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 105)) (2.11.4)
# Requirement already satisfied: pydantic-settings==2.9.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 106)) (2.9.1)
# Requirement already satisfied: pydantic_core==2.33.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 107)) (2.33.2)
# Requirement already satisfied: Pygments==2.19.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 108)) (2.19.1)
# Requirement already satisfied: pyparsing==3.2.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 109)) (3.2.3)
# Requirement already satisfied: pypdf==5.4.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 110)) (5.4.0)
# Requirement already satisfied: PyPika==0.48.9 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 111)) (0.48.9)
# Requirement already satisfied: pyproject_hooks==1.2.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 112)) (1.2.0)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 113)) (2.9.0.post0)
# Requirement already satisfied: python-dotenv==1.1.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 114)) (1.1.0)
# Requirement already satisfied: PyYAML==6.0.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 115)) (6.0.2)
# Requirement already satisfied: referencing==0.36.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 116)) (0.36.2)
# Requirement already satisfied: regex==2024.11.6 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 117)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 118)) (2.32.3)
# Requirement already satisfied: requests-oauthlib==2.0.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 119)) (2.0.0)
# Requirement already satisfied: requests-toolbelt==1.0.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 120)) (1.0.0)
# Requirement already satisfied: rich==14.0.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 121)) (14.0.0)
# Requirement already satisfied: rpds-py==0.24.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 122)) (0.24.0)
# Requirement already satisfied: rsa==4.9.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 123)) (4.9.1)
# Requirement already satisfied: safetensors==0.5.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 124)) (0.5.3)
# Requirement already satisfied: scikit-learn==1.6.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 125)) (1.6.1)
# Requirement already satisfied: scipy==1.15.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 126)) (1.15.2)
# Requirement already satisfied: sentence-transformers==4.1.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 127)) (4.1.0)
# Requirement already satisfied: setuptools==80.2.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 128)) (80.2.0)
# Requirement already satisfied: shellingham==1.5.4 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 129)) (1.5.4)
# Requirement already satisfied: six==1.17.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 130)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 131)) (1.3.1)
# Requirement already satisfied: SQLAlchemy==2.0.40 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 132)) (2.0.40)
# Requirement already satisfied: starlette==0.45.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 133)) (0.45.3)
# Requirement already satisfied: sympy==1.13.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 134)) (1.13.1)
# Requirement already satisfied: tenacity==9.1.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 135)) (9.1.2)
# Requirement already satisfied: threadpoolctl==3.6.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 136)) (3.6.0)
# Requirement already satisfied: tokenizers==0.21.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 137)) (0.21.1)
# Requirement already satisfied: torch==2.6.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 138)) (2.6.0)
# Requirement already satisfied: tqdm==4.67.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 139)) (4.67.1)
# Requirement already satisfied: transformers==4.51.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 140)) (4.51.3)
# Requirement already satisfied: triton==3.2.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 141)) (3.2.0)
# Requirement already satisfied: typer==0.15.3 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 142)) (0.15.3)
# Requirement already satisfied: typing-inspect==0.9.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 143)) (0.9.0)
# Requirement already satisfied: typing-inspection==0.4.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 144)) (0.4.0)
# Requirement already satisfied: typing_extensions==4.13.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 145)) (4.13.2)
# Requirement already satisfied: uritemplate==4.1.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 146)) (4.1.1)
# Requirement already satisfied: urllib3==2.4.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 147)) (2.4.0)
# Requirement already satisfied: uvicorn==0.34.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 148)) (0.34.2)
# Requirement already satisfied: uvloop==0.21.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 149)) (0.21.0)
# Requirement already satisfied: watchfiles==1.0.5 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 150)) (1.0.5)
# Requirement already satisfied: websocket-client==1.8.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 151)) (1.8.0)
# Requirement already satisfied: websockets==15.0.1 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 152)) (15.0.1)
# Requirement already satisfied: wrapt==1.17.2 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 153)) (1.17.2)
# Requirement already satisfied: yarl==1.20.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 154)) (1.20.0)
# Requirement already satisfied: zipp==3.21.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 155)) (3.21.0)
# Requirement already satisfied: zstandard==0.23.0 in /home/mobiledairy/Mr.HelpMate/venv/lib/python3.12/site-packages (from -r requirements.txt (line 156)) (0.23.0)

# %% [markdown]
# ## Mr. HelpMate AI
# This notebook consolidates the functionalities of the Mr. HelpMate AI repository into a single interactive notebook.

# %% [markdown]
# ## Imports and Dependencies
# Import all necessary libraries and modules.

# %%
import json
import pickle
from sentence_transformers import CrossEncoder
import google.generativeai as genai
from langchain_community.document_loaders import PyPDFLoader
from langchain_core.documents import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
import re
from sentence_transformers import SentenceTransformer
from chromadb import PersistentClient

# %% [markdown]
# ## Search with Cache
# Define a function to perform semantic search with caching support.

# %%
CACHE_FILE = "/home/mobiledairy/Mr.HelpMate/Mr.HelpMate-AI/cache/search_cache.pkl"

import os
import pickle

def search_with_cache(query, embedder, collection, top_k=5):
    cache = {}

    # Handle missing or corrupted cache file gracefully
    if os.path.exists(CACHE_FILE) and os.path.getsize(CACHE_FILE) > 0:
        try:
            with open(CACHE_FILE, "rb") as f:
                cache = pickle.load(f)
        except (EOFError, pickle.UnpicklingError):
            print("Warning: Cache file is empty or corrupted. Rebuilding cache.")
            cache = {}
    else:
        print("Cache file does not exist or is empty. Creating a new one.")

    # Return from cache if available
    if query in cache:
        return cache[query]

    # Perform embedding and retrieval
    q_embed = embedder.encode(query).tolist()
    results = collection.query(query_embeddings=[q_embed], n_results=top_k)
    docs = results["documents"][0]

    # Update and save cache
    cache[query] = docs
    with open(CACHE_FILE, "wb") as f:
        pickle.dump(cache, f)

    return docs


def rerank(query, docs, top_n=3):
    reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
    pairs = [[query, doc] for doc in docs]
    scores = reranker.predict(pairs)
    reranked = sorted(zip(docs, scores), key=lambda x: x[1], reverse=True)
    return reranked[:top_n]

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# Load the .env file
load_dotenv()

api_key = os.getenv("GENERATIVE_AI_API_KEY")
if not api_key:
    raise ValueError("API key not found. Please ensure it is set in the .env file.")

genai.configure(api_key=api_key)

def generate_answer(query, top_chunks):
    context = "\n\n".join([chunk for chunk, _ in top_chunks])
    prompt = f"""
You are Mr. HelpMate AI, a smart assistant built to help people understand complex insurance policy documents. These documents are often long and full of hidden clauses that buyers usually miss.

Your job is to carefully read the provided context and answer the user’s specific question clearly and accurately.

You must:
- Provide a concise and clear answer to the question.
- Mention the section heading (e.g., "PART IV - BENEFITS, Article 2 - Death Benefits Payable") where the information was found.
- Include the page number(s) where this content appears in the policy.
- If the answer spans multiple sections, mention all relevant headings and pages.
- Use simple, professional language that helps the user understand their policy without legal jargon.

---

Context:
{context}

Question: {query}

---

Example 1:
Question: Does this policy provide coverage for death due to an accident?

Answer: Yes, the policy includes coverage for accidental death.

Found in:
Section: PART IV - BENEFITS, Section B - Member Accidental Death and Dismemberment Insurance  
Article: Article 3 - Benefits Payable  
Pages: 49–51

---

Example 2:
Question: Is there a suicide exclusion clause in this insurance policy?

Answer: Yes, the policy does not pay a benefit if the insured dies by suicide within the first two years.

Found in:
Section: PART V - GENERAL EXCLUSIONS  
Article: Article 1 - Suicide Exclusion  
Pages: 52

---

Example 3:
Question: Are pre-existing conditions covered in this plan?

Answer: No, the policy excludes coverage for pre-existing conditions during the first 12 months.

Found in:
Section: PART III - LIMITATIONS  
Article: Article 2 - Pre-existing Condition Limitation  
Pages: 35–36

---

Now, based on the given context and user question, follow the above format to respond appropriately.

"""
    model = genai.GenerativeModel("gemini-2.0-pro-exp-02-05")
    response = model.generate_content(prompt)
    return response.text

# %%
def clean_and_group_sections(text):
    # Group by parts like "PART I - DEFINITIONS", "PART IV - BENEFITS", etc.
    section_pattern = r"(PART [IVXL]+ - .+?)(?=PART [IVXL]+ -|\Z)"
    matches = re.findall(section_pattern, text, re.DOTALL)
    return matches if matches else [text]

def load_and_split(pdf_path):
    loader = PyPDFLoader("/home/mobiledairy/Mr.HelpMate/Mr.HelpMate-AI/data/Principal-Sample-Life-Insurance-Policy.pdf")
    docs = loader.load()

    # Merge all pages to capture full structured content
    full_text = "\n".join(doc.page_content for doc in docs)
    sections = clean_and_group_sections(full_text)

    # Wrap each section into a Document with metadata
    section_docs = [
        Document(page_content=section.strip(), metadata={"section": f"Part {i+1}"})
        for i, section in enumerate(sections)
    ]

    # Chunk semantically for RAG using LangChain's splitter
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    return splitter.split_documents(section_docs)

# %% [markdown]
# ## ChromaDB Setup
# Initialize ChromaDB and the sentence embedder, and upload chunks.

# %%
def setup_chroma(chunks):
    client = PersistentClient(path="cache/chroma_db")
    collection = client.get_or_create_collection("insurance_docs")
    embedder = SentenceTransformer("sentence-transformers/all-MiniLM-L12-v2")

    for i, chunk in enumerate(chunks):
        collection.add(documents=[chunk.page_content], ids=[str(i)])
    
    return collection, embedder

# %% [markdown]
# ## PDF Loading and Chunking
# Load the PDF document and split it into manageable text chunks.

# %%
pdf_path = "/home/mobiledairy/Mr.HelpMate/Mr.HelpMate-AI/data/Principal-Sample-Life-Insurance-Policy.pdf"
chunks = load_and_split(pdf_path)

# %%
collection, embedder = setup_chroma(chunks)

# %% [markdown]
# ## Execute Queries
# Run each query: search, rerank, and generate answers.

# %%
# ---------------------------
# Query 1
# ---------------------------
query1 = "What is the grace period for premium payment?"
print("=" * 100)
print(f"Query 1: {query1}\n")

docs1 = search_with_cache(query1, embedder, collection)
reranked1 = rerank(query1, docs1)

print("🔍 Top 3 Retrieved Chunks for Query 1:\n")
for i, (text, score) in enumerate(reranked1[:3], 1):
    print(f"[{i}] Score: {score:.4f}\n{text[:300]}...\n")

print("Final Generated Answer for Query 1:\n")
response1 = generate_answer(query1, reranked1[:3])
print(response1)
print("=" * 100 + "\n\n")
# Out:
# ====================================================================================================
# Query 1: What is the grace period for premium payment?
#
# 🔍 Top 3 Retrieved Chunks for Query 1:
#
# [1] Score: 8.5812
# will be due on the first of each Insurance Month.  Except for the first premium, a Grace Period of
# 31 days will be allowed for payment of premium.  "Grace Period" means the first 31- day period
# following a premium due date.  The Group Policy will remain in fo rce until the end of the Grace...
#
# [2] Score: 2.5242
# This policy has been updated effective  January 1, 2014
#
#
# PART II - POLICY ADMINISTRATION
# GC 6004 Section B - Premiums, Page 1
#
# Section B - Premiums
#
#
# Article 1 - Payment Responsibility; Due Dates; Grace Period...
#
# [3] Score: 1.8549
# Dependent Rights Article 9
#
#  Policy Interpretation Article 10
#
#  Electronic Transactions Article 11
#
#
#  Section B – Premium
#
#
#  Payment Responsibility; Due Dates; Grace Period Article 1
#  Premium Rates Article 2
#  Premium Rate Changes Article 3
#  Premium Amount Article 4...
#
# Final Generated Answer for Query 1:
#
# Answer: The grace period for premium payment is 31 days following the premium due date.
#
# Found in:
# Section: PART II - POLICY ADMINISTRATION, Section B - Premiums
# Article: Article 1 - Payment Responsibility; Due Dates; Grace Period
# Pages: 1
# ====================================================================================================

# %%
# ---------------------------
# Query 2
# ---------------------------
query2 = "Is suicide covered under the policy?"
print("=" * 100)
print(f"Query 2: {query2}\n")

docs2 = search_with_cache(query2, embedder, collection)
reranked2 = rerank(query2, docs2)

print("🔍 Top 3 Retrieved Chunks for Query 2:\n")
for i, (text, score) in enumerate(reranked2[:3], 1):
    print(f"[{i}] Score: {score:.4f}\n{text[:300]}...\n")

print("Final Generated Answer for Query 2:\n")
response2 = generate_answer(query2, reranked2[:3])
print(response2)
print("=" * 100 + "\n\n")
# Out:
# ====================================================================================================
# Query 2: Is suicide covered under the policy?
#
# 🔍 Top 3 Retrieved Chunks for Query 2:
#
# [1] Score: -4.7528
# This policy has been updated effective  January 1, 2014
#
#       PART IV - BENEFITS
# GC 6015  Section B - Member Accidental Death and
# Dismemberment Insurance, Page 6
#
#
#
# a. willful self-injury or self-destruction, while sane or insane; or...
#
# [2] Score: -7.3011
# This policy has been updated effective January 1, 2014
#
#
#
# GC 6001 TABLE OF CONTENTS, PAGE 2
#
#
#
#  Section A – Eligibility
#
#
#  Member Life Insurance Article 1
#
#  Member Accidental Death and Dismemberment Insurance Article 2
#
#  Dependent Life Insurance Article 3...
#
# [3] Score: -7.3558
# This policy has been updated effective  January 1, 2014
#
#
# PART IV - BENEFITS
# GC 6013  Section A - Member Life Insurance, Page 2
#
# Member's death, the Death B enefits Payable may be withheld until additional information has
# been received or the trial has been held....
#
# Final Generated Answer for Query 2:
#
# Based on the information provided, the policy does not cover death resulting from willful self-injury or self-destruction (which includes suicide) under the Accidental Death and Dismemberment Insurance section.
#
# Found in:
# Section: PART IV - BENEFITS, Section B - Member Accidental Death and Dismemberment Insurance
# Page: 6 (Reference GC 6015)
# ====================================================================================================

# %%
# ---------------------------
# Query 3
# ---------------------------
query3 = "Can the policyholder surrender the policy early?"
print("=" * 100)
print(f"Query 3: {query3}\n")

docs3 = search_with_cache(query3, embedder, collection)
reranked3 = rerank(query3, docs3)

print("🔍 Top 3 Retrieved Chunks for Query 3:\n")
for i, (text, score) in enumerate(reranked3[:3], 1):
    print(f"[{i}] Score: {score:.4f}\n{text[:300]}...\n")

print("Final Generated Answer for Query 3:\n")
response3 = generate_answer(query3, reranked3[:3])
print(response3)
print("=" * 100 + "\n\n")
# Out:
# ====================================================================================================
# Query 3: Can the policyholder surrender the policy early?
#
# 🔍 Top 3 Retrieved Chunks for Query 3:
#
# [1] Score: 1.2513
# Policyholder relocates to a state where this Group Policy is not marketed, by giving the
# Policyholder 31 days advanced notice in Writing.
#
#
# Article 4 - Policyholder Responsibility to Members
#
# If this Group Policy terminates for any reason, the Policyholder must:...
#
# [2] Score: -6.1964
# extension.
#
# In actual practice, benefits under this Group Policy will be payable sooner, provided The
# Principal receives complete and proper proof of loss.  Further, if a claim is not payable or cannot
# be processed, The Principal will submit a detailed explanation of the basis for its denial....
#
# [3] Score: -8.5765
# by an officer of The Principal.
#
# The Principal reserves the right to change this Group Policy as follows:
#
# a. Any or all provisions of this Group Policy may be amended or changed at any time,
# including retroactive changes, to the extent necessary to meet the requirements of any law...
#
# Final Generated Answer for Query 3:
#
# Based on the provided text, there is no information about whether the policyholder can surrender the policy early.
#
# The context discusses:
# *   Termination initiated by the insurer due to the policyholder relocating (Page not specified).
# *   The policyholder's responsibilities if the policy terminates (Article 4 - Policyholder Responsibility to Members, Page not specified).
# *   Claim processing and denial (Page not specified).
# *   The insurer's right to change the policy (Page not specified).
#
# However, the specific conditions or procedures for a policyholder choosing to surrender the policy early are not mentioned in this section.
# ====================================================================================================
